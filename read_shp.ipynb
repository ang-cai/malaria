# %% [markdown]
# # Read SHP

# %%
import geopandas as gpd

# %%
country = gpd.read_file("East Africa Standardized Data/ethiopia.shp")

# %%
country.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 65 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DHSID       305 non-null    object
#  1   GPS_Datase  305 non-null    object
#  2   DHSCC       305 non-null    object
#  3   DHSYEAR     305 non-null    float64
#  4   LATNUM      305 non-null    float64
#  5   LONGNUM     305 non-null    float64
#  6   Day_Land_S  305 non-null    float64
#  7   Day_Land_1  305 non-null    float64
#  8   Diurnal_Te  305 non-null    float64
#  9   Diurnal__1  305 non-null    float64
#  10  Drought_Ep  305 non-null    float64
#  11  Elevation   305 non-null    float64
#  12  Enhanced_V  305 non-null    float64
#  13  Enhanced_1  305 non-null    float64
#  14  Frost_Days  305 non-null    float64
#  15  Frost_Da_1  305 non-null    float64
#  16  Global_Hum  305 non-null    float64
#  17  Growing_Se  305 non-null    float64
# ...

# %%
country.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
