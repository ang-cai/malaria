# %% [markdown]
# # Read SHP

# %%
import geopandas as gpd

# %%
country = gpd.read_file("Burundi Geodata/BUGE71FL.shp")

# %%
country
# Out:
#               DHSID DHSCC  DHSYEAR  DHSCLUST CCFIPS ADM1FIPS ADM1FIPSNA  \
# 0    BU201600000001    BU   2016.0       1.0     BY     NULL       NULL
# 1    BU201600000002    BU   2016.0       2.0     BY     NULL       NULL
# 2    BU201600000003    BU   2016.0       3.0     BY     NULL       NULL
# 3    BU201600000004    BU   2016.0       4.0     BY     NULL       NULL
# 4    BU201600000005    BU   2016.0       5.0     BY     NULL       NULL
# ..              ...   ...      ...       ...    ...      ...        ...
# 549  BU201600000550    BU   2016.0     550.0     BY     NULL       NULL
# 550  BU201600000551    BU   2016.0     551.0     BY     NULL       NULL
# 551  BU201600000552    BU   2016.0     552.0     BY     NULL       NULL
# 552  BU201600000553    BU   2016.0     553.0     BY     NULL       NULL
# 553  BU201600000554    BU   2016.0     554.0     BY     NULL       NULL
#
#     ADM1SALBNA ADM1SALBCO  ADM1DHS  ... DHSREGCO          DHSREGNA SOURCE  \
# ...
