# %%
import rioxarray

# Reads and plots a raster
uganda_tif = rioxarray.open_rasterio("Uganda Malaria Data/mock_malaria_prevelance_uganda_2km_2018.tif")

uganda_tif.plot()

# %%
uganda_tif = rioxarray.open_rasterio("Uganda Malaria Data/mock_malaria_prevelance_uganda_2km_2000.tif")

uganda_tif.plot()
